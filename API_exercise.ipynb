# %%
from config import YOUTUBE_API_KEY
from googleapiclient.discovery import build
from IPython.display import JSON
import pandas as pd

# %%
api_service_name = "youtube"
api_version = "v3"

channel_ids = [
    "UCpfg5f3R5uqQM6Q2dI2KU2A",
    # Can add more channels
]

# Get credentials and create an API client

youtube = build(
    api_service_name, api_version, developerKey=YOUTUBE_API_KEY)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=",".join(channel_ids)
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'yw738YMZc3gP7RC__J7cHFos65A', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': '3maBhABt2g4gFXT4F7lUWEmrIEE', 'id': 'UCpfg5f3R5uqQM6Q2dI2KU2A', 'snippet': {'title': 'Portal', 'description': 'İlgimi çeken konular hakkında videolar hazırlıyorum.\n\n', 'customUrl': '@portalvideo', 'publishedAt': '2019-05-18T09:25:03Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/XhlQ2Zh5oN1Cu67twlsEIxl-yjewNLJxoCxZCPR6BMdVzW4EhE3m_O5yPzrxv_P_0hrHKd2tkmg=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/XhlQ2Zh5oN1Cu67twlsEIxl-yjewNLJxoCxZCPR6BMdVzW4EhE3m_O5yPzrxv_P_0hrHKd2tkmg=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/XhlQ2Zh5oN1Cu67twlsEIxl-yjewNLJxoCxZCPR6BMdVzW4EhE3m_O5yPzrxv_P_0hrHKd2tkmg=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Portal', 'description': 'İlgimi çeken konular hakkında videolar hazırlıyorum.\n\n'}, 'country': 'TR'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUpfg5f3R5uqQM6Q2dI2KU2A'}}, 'statistics': {'viewCount': '118400948', 'subscriberCount': '825000', 'hiddenSubscriberCount': False, 'videoCount': '143'}}]}

# %%
JSON(response)

# %%
api_service_name = "youtube"
api_version = "v3"

channel_ids = [
    "UUCpfg5f3R5uqQM6Q2dI2KU2A",
    # Can add more channels
]

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey=YOUTUBE_API_KEY)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=",".join(channel_ids)
    )

    response = request.execute()

    # loop through items in response
    for item in response["items"]:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
channel_ids = get_channel_stats(youtube, channel_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 channel_ids = get_channel_stats(youtube, channel_ids)
#
# Cell In[6], line 12, in get_channel_stats(youtube, channel_ids)
#       9 response = request.execute()
#      11 # loop through items in response
# ---> 12 for item in response["items"]:
#      13     data = {'channelName': item['snippet']['title'],
#      14             'subscribers': item['statistics']['subscriberCount'],
#      15             'views': item['statistics']['viewCount'],
#      16             'totalVideos': item['statistics']['videoCount'],
#      17             'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
#      18     }
#      19     all_data.append(data)
#
# KeyError: 'items'

# %%
channel_ids
# Out:
# ['UUCpfg5f3R5uqQM6Q2dI2KU2A']

# %%
request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId="UUYO_jab_esuFRV4b17AJtAw"
    )
response = request.execute()

# %%
JSON(response)

# %%
def get_video_ids(youtube, playlist_id):
    video_ids = []

    request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id
        )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    return video_ids

# %%
playlist_id = "UUYO_jab_esuFRV4b17AJtAw"

video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['tjIOqIr80ns', 'W1gW1dHRsOw', 'p9i3cYMQtBY', 'X4jpqCu-wlA', 'GOSezO0CHss']

# %%
def get_video_ids(youtube, playlist_id):
    video_ids = []

    request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50
        )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')    

        
    return video_ids

# %%
playlist_id = "UUYO_jab_esuFRV4b17AJtAw"

video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 157

# %%
import requests
import pandas as pd
from config import YOUTUBE_API_KEY

# %%
CHANNEL_ID = "UCpfg5f3R5uqQM6Q2dI2KU2A"
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyAjul0ki9SFfI9f4cTApU0E0RLM-qaXRQE&channelId=UCpfg5f3R5uqQM6Q2dI2KU2A&part=snippet,id&order=date&maxResults=1000

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'x5eOs8lKC0QkkurZatkqxWtbYVk',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 156, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'FYgfL2TS-C8ixYutH9lKo7XFv7I',
#    'id': {'kind': 'youtube#video', 'videoId': '6Wy-tXo-9tc'},
#    'snippet': {'publishedAt': '2023-12-19T15:28:49Z',
#     'channelId': 'UCpfg5f3R5uqQM6Q2dI2KU2A',
#     'title': 'Kadının Öfkesi Bir Başkadır',
#     'description': 'Podcast: https://open.spotify.com/show/7fvBlgg1Xuhe2hG0mlGKWg Instagram: https://www.instagram.com/canaybalik Twitter: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Wy-tXo-9tc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6Wy-tXo-9tc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6Wy-tXo-9tc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Portal',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-19T15:28:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Smt4CyFzNUreniaUd-dfF86Xgjg',
#    'id': {'kind': 'youtube#video', 'videoId': 'godwPYZ3ogI'},
#    'snippet': {'publishedAt': '2023-12-10T10:31:16Z',
#     'channelId': 'UCpfg5f3R5uqQM6Q2dI2KU2A',
#     'title': 'Arada Kafa Dinlemek Gerekiyor',
#     'description': 'Georges Seurat, A Sunday Afternoon on the Island of La Grande Jatte)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/godwPYZ3ogI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/godwPYZ3ogI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi
/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Portal',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-27T13:04:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i-XMhg5ZCI2JJgucobni7GkOKHA',
#    'id': {'kind': 'youtube#video', 'videoId': 'pqdH4o7YMcA'},
#    'snippet': {'publishedAt': '2023-07-24T18:29:56Z',
#     'channelId': 'UCpfg5f3R5uqQM6Q2dI2KU2A',
#     'title': 'Felaketlerin İnsana Bu Kadar Yakın Olması Sinir Bozucu',
#     'description': 'Twitter: https://twitter.com/canaybalik Instagram: https://www.instagram.com/canaybalik Podcast: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pqdH4o7YMcA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pqdH4o7YMcA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pqdH4o7YMcA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Portal',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-24T18:29:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ah-n-AjQK32HHDESSVWp3rLiMEE',
#    'id': {'kind': 'youtube#video', 'videoId': 'JzlebT3El_I'},
#    'snippet': {'publishedAt': '2023-07-21T13:55:27Z',
#     'channelId': 'UCpfg5f3R5uqQM6Q2dI2KU2A',
#     'title': 'Maske, Bıçak ve Vahşet',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JzlebT3El_I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JzlebT3El_I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JzlebT3El_I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Portal',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-21T13:55:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FYbXfBuRyy_v38ylQpPkI5Eel6c',
#    'id': {'kind': 'youtube#video', 'videoId': 'wVe3dBwdh_Q'},
#    'snippet': {'publishedAt': '2023-07-08T18:54:13Z',
#     'channelId': 'UCpfg5f3R5uqQM6Q2dI2KU2A',
#     'title': 'Şeytan&#39;ın Sanatı',
#     'description': 'Twitter: https://twitter.com/canaybalik Instagram: https://www.instagram.com/canaybalik Podcast: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wVe3dBwdh_Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wVe3dBwdh_Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wVe3dBwdh_Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Portal',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-08T18:54:13Z'}}]}

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'FYgfL2TS-C8ixYutH9lKo7XFv7I',
#  'id': {'kind': 'youtube#video', 'videoId': '6Wy-tXo-9tc'},
#  'snippet': {'publishedAt': '2023-12-19T15:28:49Z',
#   'channelId': 'UCpfg5f3R5uqQM6Q2dI2KU2A',
#   'title': 'Kadının Öfkesi Bir Başkadır',
#   'description': 'Podcast: https://open.spotify.com/show/7fvBlgg1Xuhe2hG0mlGKWg Instagram: https://www.instagram.com/canaybalik Twitter: ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Wy-tXo-9tc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/6Wy-tXo-9tc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/6Wy-tXo-9tc/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Portal',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-12-19T15:28:49Z'}}

# %%
response["items"][0]['id']['videoId']
# Out:
# '6Wy-tXo-9tc'

# %%
response["items"][0]['snippet']['title']
# Out:
# 'Kadının Öfkesi Bir Başkadır'

# %%
response["items"][0]['snippet']['publishedAt']
# Out:
# '2023-12-19T15:28:49Z'

# %%
video_title = response["items"][0]['snippet']['title']
video_id = response["items"][0]['id']['videoId']
upload_time = response["items"][0]['snippet']['publishedAt']
upload_time = str(upload_time).split("T")[0]
print(video_title)
print(video_id)
print(upload_time)
# Out:
# Kadının Öfkesi Bir Başkadır
# 6Wy-tXo-9tc
# 2023-12-19

# %%
# for loop in response
for video in response["items"]:
    if video['id']['kind'] == "youtube#video":
        video_title = video['snippet']['title']
        print(video_title)
# Out:
# Kadının Öfkesi Bir Başkadır
# Arada Kafa Dinlemek Gerekiyor
# Kapı Deliğinden Bakma!
# Bu Kadınlar Şimdi Ne Yapacak?
# Mario Oynarken Hayatı Sorgulamak
# Tanrı Neden Oğlumu Öldürmemi İstiyor?
# Acı ile Sürünmek
# Ölüyormuş Gibi Çek
# Gelin Öfkesi
# Açım ve Seni Yemek İstiyorum
# Ölümün İmparatorluğu
# Ayıp Ayıp
# E Çocuklar Korkar Bundan
# Aramızda Kalsın
# Bu Kediler Neden Ürpertici?
# Aşkından Deliren O Kadın
# Ölüm Seni Unutmaz
# Teletabiler Ürpertici Ya
# Değdi Mi Çocuğun Ölümüne?
# Ulan O Sineğin Orada Ne İşi Var?
# Bu Kadın Çok Güzel ama Acımasız
# Hayran Bırakıyorsun Beni Kendine
# Ben Oğlumu Öldürdüm
# Cehennem Böyle Bir Yer
# Sakın Aşağı Bakma!
# İnsanın En Ağır Yükü Gerçekleştiremediği Potansiyeli
# Çocukları Korkutacaksan Onlara Masal Anlat
# Gece Vakti Gelen O Melankoli
# Ölümün Yaklaştığında Sadakatini Koruyabilir Misin?
# Bu Kızın Başına Neden Hep Kötü Şeyler Geliyor?
# Beni İyileştirmeye Mi Yoksa Öldürmeye Mi Geldin?
# Bazen Aşkı Feda Etmen Gerekir
# Savaşta Deliren Asker?
# Fakir ama Güzel Kız. Yaşlı ama Zengin Adam.
# Bu Robot Acı Çekiyor
# Çirkinsin Ama Detayın Güzel
# Nietzsche&#39;nin Sokrates&#39;e Çekiçle Dalması
# Deli Annenin Öfkesi
# O Korkunç Ev
# Bu Soytarı Neden Üzgün?
# Bir Palyaçonun Hayat Mücadelesi
# Bu Kadın Hem Fena Hem de Başa Bela
# Felaketlerin İnsana Bu Kadar Yakın Olması Sinir Bozucu
# Maske, Bıçak ve Vahşet
# Şeytan&#39;ın Sanatı

# %%
video_id = "6Wy-tXo-9tc"
video_url_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY

video_response = requests.get(video_url_endpoint).json()

# %%
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'Sm5L4tBPvudGI1P2Tdx8B_GBtmY',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'qfQzs7kpUfBrUsTkQppPtmjKv7Q',
#    'id': '6Wy-tXo-9tc',
#    'statistics': {'viewCount': '164630',
#     'likeCount': '15753',
#     'favoriteCount': '0',
#     'commentCount': '726'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
video_response["items"][0]["statistics"]
# Out:
# {'viewCount': '164630',
#  'likeCount': '15753',
#  'favoriteCount': '0',
#  'commentCount': '726'}

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_time = video['snippet']['publishedAt']
        upload_date= str(upload_time).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        print(video_title)
        print(video_id)
        print(upload_date)
        print(view_count)
        print(like_count)
        print("\n")
# Out:
# Kadının Öfkesi Bir Başkadır
# 6Wy-tXo-9tc
# 2023-12-19
# 164630
# 15754
#
#
# Arada Kafa Dinlemek Gerekiyor
# godwPYZ3ogI
# 2023-12-10
# 254125
# 26272
#
#
# Kapı Deliğinden Bakma!
# OfdHd94kJ3s
# 2023-12-07
# 715513
# 37590
#
#
# Bu Kadınlar Şimdi Ne Yapacak?
# ukmZFn5IdOE
# 2023-12-01
# 291655
# 35439
#
#
# Mario Oynarken Hayatı Sorgulamak
# 0QoWtM1bWeo
# 2023-11-28
# 737666
# 43250
#
#
# Tanrı Neden Oğlumu Öldürmemi İstiyor?
# bGqnv7401Hg
# 2023-11-24
# 185921
# 13679
#
#
# Acı ile Sürünmek
# B2ih4VK8Tcs
# 2023-11-23
# 1011288
# 68474
#
#
# Ölüyormuş Gibi Çek
# WvzQ1y_LFJU
# 2023-11-20
# 332763
# 21422
#
#
# Gelin Öfkesi
# diEDCMvPkb8
# 2023-11-17
# 768347
# 54182
#
#
# Açım ve Seni Yemek İstiyorum
# rXS5uEkqJbM
# 2023-11-15
# 338250
# 20693
#
#
# Ölümün İmparatorluğu
# ZtddnhXJIGk
# 2023-11-12
# 897211
# 58757
#
#
# Ayıp Ayıp
# mKF6M76M5qU
# 2023-11-08
# 2281615
# 115525
#
#
# E Çocuklar Korkar Bundan
# Tl8evjiFY8g
# 2023-11-05
# 965175
# 70992
#
#
# Aramızda Kalsın
# DLpdS_1zTpc
# 2023-11-01
# 541380
# 52946
#
#
# Bu Kediler Neden Ürpertici?
# dlHYlCbxYUw
# 2023-10-30
# 729475
# 48987
#
#
# Aşkından Deliren O Kadın
# 7dJOf5_xQ1M
# 2023-10-27
# 196417
# 16210
#
#
# Ölüm Seni Unutmaz
# vgYbd3N7M8U
# 2023-10-26
# 689927
# 53369
#
#
# Teletabiler Ürpertici Ya
# L3DbK1yKVXY
# 2023-10-24
# 1424405
# 67279
#
#
# Değdi Mi Çocuğun Ölümüne?
# wPo0g0IuY9o
# 2023-10-19
# 4400853
# 279100
#
#
# Ulan O Sineğin Orada Ne İşi Var?
# Mb69Krq_xqY
# 2023-10-17
# 1203333
# 82255
#
#
# Bu Kadın Çok Güzel ama Acımasız
# kRncFamA41c
# 2023-10-04
# 845427
# 68541
#
#
# Hayran Bırakıyorsun Beni Kendine
# G0yFoaitLFA
# 2023-10-02
# 218719
# 24118
#
#
# Ben Oğlumu Öldürdüm
# xByxeswE2o8
# 2023-10-01
# 392094
# 28427
#
#
# Cehennem Böyle Bir Yer
# BOVj2QPjly0
# 2023-09-28
# 461585
# 49097
#
#
# Sakın Aşağı Bakma!
# mTOug-w8A8k
# 2023-09-27
# 4676561
# 212748
#
#
# İnsanın En Ağır Yükü Gerçekleştiremediği Potansiyeli
# lsNf9_c2WWQ
# 2023-09-19
# 641399
# 44320
#
#
# Çocukları Korkutacaksan Onlara Masal Anlat
# 8-hLBDZx0EA
# 2023-09-17
# 909684
# 62171
#
#
# Gece Vakti Gelen O Melankoli
# jPi7WGwvdHw
# 2023-09-14
# 498145
# 47172
#
#
# Ölümün Yaklaştığında Sadakatini Koruyabilir Misin?
# Re9mVlcpJB8
# 2023-09-12
# 1419830
# 109750
#
#
# Bu Kızın Başına Neden Hep Kötü Şeyler Geliyor?
# vSj5jjltDQk
# 2023-09-10
# 554265
# 34263
#
#
# Beni İyileştirmeye Mi Yoksa Öldürmeye Mi Geldin?
# hxnX3nlTcag
# 2023-09-08
# 1463680
# 78382
#
#
# Bazen Aşkı Feda Etmen Gerekir
# bTsGGMNccqE
# 2023-09-06
# 1273142
# 119257
#
#
# Savaşta Deliren Asker?
# ZquEZNs0LRg
# 2023-09-04
# 3128487
# 107382
#
#
# Fakir ama Güzel Kız. Yaşlı ama Zengin Adam.
# SIcmvkSPddg
# 2023-08-26
# 2214671
# 125954
#
#
# Bu Robot Acı Çekiyor
# L4FSj6GEZAU
# 2023-08-23
# 20275548
# 500261
#
#
# Çirkinsin Ama Detayın Güzel
# 91aLi6Dhyvk
# 2023-08-19
# 4314750
# 159409
#
#
# Nietzsche&#39;nin Sokrates&#39;e Çekiçle Dalması
# ihGHfuyA8vI
# 2023-08-18
# 224993
# 13047
#
#
# Deli Annenin Öfkesi
# JDcT0sA7yps
# 2023-08-14
# 1230371
# 80730
#
#
# O Korkunç Ev
# wWpBnw8Xbnw
# 2023-08-10
# 319697
# 25370
#
#
# Bu Soytarı Neden Üzgün?
# 1P7LtXnvXag
# 2023-08-06
# 389350
# 27430
#
#
# Bir Palyaçonun Hayat Mücadelesi
# 8bfj0F9itno
# 2023-08-02
# 974777
# 69801
#
#
# Bu Kadın Hem Fena Hem de Başa Bela
# WEe9WjwCKbg
# 2023-07-27
# 687481
# 35923
#
#
# Felaketlerin İnsana Bu Kadar Yakın Olması Sinir Bozucu
# pqdH4o7YMcA
# 2023-07-24
# 307769
# 18541
#
#
# Maske, Bıçak ve Vahşet
# JzlebT3El_I
# 2023-07-21
# 768985
# 37957
#
#
# Şeytan&#39;ın Sanatı
# wVe3dBwdh_Q
# 2023-07-08
# 383565
# 21264

# %%
df = pd.DataFrame()  # Create an empty DataFrame

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        # ... (extract video information)

        # Create a new DataFrame row for the current video
        video_df = pd.DataFrame({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, index=[0])  # Add an index to avoid potential issues

        # Concatenate the new row with the existing DataFrame
        df = pd.concat([df, video_df], ignore_index=True)

# Now df holds all the collected video information

# %%
import requests
import pandas as pd
import time
from config import YOUTUBE_API_KEY

# %%
def get_video_statistics(video_id, youtube_api_key):
    # collecting video statistics
    video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+youtube_api_key
    video_stats_response = requests.get(video_stats_url).json()

    view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
    like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

    return view_count, like_count

# %%
def get_videos_from_channel(df, channel_id, youtube_api_key):
    # API call
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+youtube_api_key+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000"+pageToken
    
    response = requests.get(url).json()
    time.sleep(3)

    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_title = video['snippet']['title']
            video_id = video['id']['videoId']
            upload_date = video['snippet']['publishedAt']
            upload_date= str(upload_date).split("T")[0]

            view_count, like_count = get_video_statistics(video_id, youtube_api_key)

            # save 
            df = df._append({
                "video_id": video_id,
                "video_title": video_title,
                "upload_date": upload_date,
                "view_count": view_count,
                "like_count": like_count
            }, 
            ignore_index = True
            )
    return df

# %%
CHANNEL_ID = "UCpfg5f3R5uqQM6Q2dI2KU2A"

df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 
youtube_data = get_videos_from_channel(df, CHANNEL_ID, YOUTUBE_API_KEY)

# %%
youtube_data.head()
# Out:
#       video_id                       video_title upload_date view_count  \
# 0  6Wy-tXo-9tc       Kadının Öfkesi Bir Başkadır  2023-12-19     164703
# 1  godwPYZ3ogI     Arada Kafa Dinlemek Gerekiyor  2023-12-10     254142
# 2  OfdHd94kJ3s            Kapı Deliğinden Bakma!  2023-12-07     715538
# 3  ukmZFn5IdOE     Bu Kadınlar Şimdi Ne Yapacak?  2023-12-01     291674
# 4  0QoWtM1bWeo  Mario Oynarken Hayatı Sorgulamak  2023-11-28     737690
#
#   like_count
# 0      15756
# 1      26273
# 2      37590
# 3      35439
# 4      43249
